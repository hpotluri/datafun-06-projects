# %% [markdown]
# # US Weather Events Dataset
#
# #### Name: Harinya Potluri
# #### Date: 09/27/2023

# %% [markdown]
# ## Section 1-Load - Read from a data file into a pandas DataFrame.

# %%
import pandas as pd

weather_events_df = pd.read_csv("WeatherEvents_Jan2016-Dec2022.csv")
weather_events_df
# Out:
#            EventId  Type  Severity       StartTime(UTC)         EndTime(UTC)  \
# 0              W-1  Snow     Light  2016-01-06 23:14:00  2016-01-07 00:34:00
# 1              W-2  Snow     Light  2016-01-07 04:14:00  2016-01-07 04:54:00
# 2              W-3  Snow     Light  2016-01-07 05:54:00  2016-01-07 15:34:00
# 3              W-4  Snow     Light  2016-01-08 05:34:00  2016-01-08 05:54:00
# 4              W-5  Snow     Light  2016-01-08 13:54:00  2016-01-08 15:54:00
# ...            ...   ...       ...                  ...                  ...
# 8627176  W-9091890  Snow     Light  2022-12-21 23:00:00  2022-12-21 23:42:00
# 8627177  W-9091891  Snow  Moderate  2022-12-21 23:42:00  2022-12-21 23:53:00
# 8627178  W-9091892  Cold    Severe  2022-12-21 23:53:00  2022-12-24 02:53:00
# 8627179  W-9091893  Cold    Severe  2022-12-24 03:53:00  2022-12-24 07:53:00
# 8627180  W-9091894  Cold    Severe  2022-12-24 09:53:00  2022-12-24 11:53:00
#
# ...

# %% [markdown]
# ## Section 2-View - Display the first 5 rows and the last 5 rows.

# %%
weather_events_df.head()
# Out:
#   EventId  Type Severity       StartTime(UTC)         EndTime(UTC)  \
# 0     W-1  Snow    Light  2016-01-06 23:14:00  2016-01-07 00:34:00
# 1     W-2  Snow    Light  2016-01-07 04:14:00  2016-01-07 04:54:00
# 2     W-3  Snow    Light  2016-01-07 05:54:00  2016-01-07 15:34:00
# 3     W-4  Snow    Light  2016-01-08 05:34:00  2016-01-08 05:54:00
# 4     W-5  Snow    Light  2016-01-08 13:54:00  2016-01-08 15:54:00
#
#    Precipitation(in)     TimeZone AirportCode  LocationLat  LocationLng  \
# 0               0.00  US/Mountain        K04V      38.0972    -106.1689
# 1               0.00  US/Mountain        K04V      38.0972    -106.1689
# 2               0.03  US/Mountain        K04V      38.0972    -106.1689
# 3               0.00  US/Mountain        K04V      38.0972    -106.1689
# 4               0.00  US/Mountain        K04V      38.0972    -106.1689
#
#        City    County State  ZipCode
# 0  Saguache  Saguache    CO  81149.0
# 1  Saguache  Saguache    CO  81149.0
# ...

# %%
weather_events_df.tail()
# Out:
#            EventId  Type  Severity       StartTime(UTC)         EndTime(UTC)  \
# 8627176  W-9091890  Snow     Light  2022-12-21 23:00:00  2022-12-21 23:42:00
# 8627177  W-9091891  Snow  Moderate  2022-12-21 23:42:00  2022-12-21 23:53:00
# 8627178  W-9091892  Cold    Severe  2022-12-21 23:53:00  2022-12-24 02:53:00
# 8627179  W-9091893  Cold    Severe  2022-12-24 03:53:00  2022-12-24 07:53:00
# 8627180  W-9091894  Cold    Severe  2022-12-24 09:53:00  2022-12-24 11:53:00
#
#          Precipitation(in)     TimeZone AirportCode  LocationLat  LocationLng  \
# 8627176               0.01  US/Mountain        KBVR      42.5833    -108.2833
# 8627177               0.04  US/Mountain        KBVR      42.5833    -108.2833
# 8627178               0.00  US/Mountain        KBVR      42.5833    -108.2833
# 8627179               0.00  US/Mountain        KBVR      42.5833    -108.2833
# 8627180               0.00  US/Mountain        KBVR      42.5833    -108.2833
#
# ...

# %% [markdown]
# ## Section 3-Describe: Use the DataFrame describe() function to calculate basic descriptive statistics for all numeric columns.

# %%
weather_events_df.describe()
# Out:
#        Precipitation(in)   LocationLat   LocationLng       ZipCode
# count       8.627181e+06  8.627181e+06  8.627181e+06  8.557982e+06
# mean        9.287441e-02  3.878602e+01 -9.191172e+01  5.241150e+04
# std         8.870326e-01  5.467708e+00  1.350340e+01  2.573249e+04
# min         0.000000e+00  2.455710e+01 -1.245550e+02  1.022000e+03
# 25%         0.000000e+00  3.459950e+01 -9.782360e+01  3.121600e+04
# 50%         0.000000e+00  3.934510e+01 -8.977340e+01  5.391300e+04
# 75%         5.000000e-02  4.306220e+01 -8.194720e+01  7.350300e+04
# max         1.104130e+03  4.894020e+01 -6.779280e+01  9.936200e+04

# %% [markdown]
# ## Section 4-Series: Use the Series method describe() to calculate the descriptive stats for all category/text columns.

# %% [markdown]
# #### Description of Type column

# %%
weather_events_df.Type.describe()
# Out:
# count     8627181
# unique          7
# top          Rain
# freq      5000794
# Name: Type, dtype: object

# %% [markdown]
# #### Description of Severity column

# %%
weather_events_df.Severity.describe()
# Out:
# count     8627181
# unique          6
# top         Light
# freq      5149786
# Name: Severity, dtype: object

# %% [markdown]
# #### Description of TimeZone column

# %%
weather_events_df.TimeZone.describe()
# Out:
# count        8627181
# unique             4
# top       US/Central
# freq         3559091
# Name: TimeZone, dtype: object

# %% [markdown]
# #### Description of AirportCode column

# %%
weather_events_df.AirportCode.describe()
# Out:
# count     8627181
# unique       2071
# top          K3TH
# freq        15760
# Name: AirportCode, dtype: object

# %% [markdown]
# #### Description of City column

# %%
weather_events_df.City.describe()
# Out:
# count          8610269
# unique            1716
# top       Jacksonville
# freq             35711
# Name: City, dtype: object

# %% [markdown]
# #### Description of County column

# %%
weather_events_df.County.describe()
# Out:
# count     8627181
# unique       1100
# top       Lincoln
# freq        87499
# Name: County, dtype: object

# %% [markdown]
# #### Description of State column

# %%
weather_events_df.State.describe()
# Out:
# count     8627181
# unique         48
# top            TX
# freq       583234
# Name: State, dtype: object

# %% [markdown]
# ## Section 5-Unique: Use the Series method unique() to get unique category values.

# %% [markdown]
# #### Unique values of City column

# %%
weather_events_df.City.unique()
# Out:
# array(['Saguache', 'Altus', 'Albert Lea', ..., 'Camdenton',
#        'Battle Mountain', 'Rock River'], dtype=object)

# %% [markdown]
# #### Unique values of AirportCode column

# %%
weather_events_df.AirportCode.unique().tolist()
# Out:
# ['K04V',
#  'KAXS',
#  'KAEL',
#  'KBTR',
#  'KCMY',
#  'KDIJ',
#  'KGRR',
#  'KHUT',
#  'KEMM',
#  'KPSF',
#  'KMKC',
#  'KRVS',
#  'KLRU',
#  'KNBT',
#  'KSPA',
#  'KTTA',
#  'KWST',
#  'KORH',
#  'KFPK',
#  'KJGG',
#  'KMKE',
#  'KHVN',
#  'KSPB',
#  'KDIK',
#  'KRWF',
#  'KTTD',
#  'K04W',
#  'KWVI',
#  'KAXX',
#  'KJHW',
#  'KAXN',
#  'KALS',
#  'KCAK',
#  'KBKX',
#  'KCMR',
#  'KCXP',
#  'KDSM',
#  'KELP',
#  'K82V',
#  'KFFC',
#  'KFYG',
#  'KGRD',
#  'KMIC',
#  'KHLR',
#  'KJER',
#  'KLGD',
#  'KIBM',
#  'KLXT',
#  'KOQT',
#  'KSTP',
#  'KTPH',
#  'KVER',
#  'K0J4',
#  'KRSV',
#  'KNSI',
#  'KSGT',
#  'KMSS',
#  'KPWK',
#  'KPIA',
#  'K2D5',
#  'KGRF',
#  'KLXV',
#  'KICL',
#  'KMIE',
#  'KOQU',
#  'KSGU',
#  'KHLX',
#  'KRSW',
#  'KDSV',
#  'KBLF',
#  'KJES',
#  'KPIB',
#  'KNTU',
#  'KALW',
#  'KCMX',
#  'KMSV',
#  'K8A0',
#  'KCXY',
#  'K06D',
#  'KSTS',
#  'KELY',
#  'KFFL',
#  'KCAO',
#  'KPWM',
#  'KTPL',
#  'KFYJ',
#  'KLGU',
#  'KVES',
#  'KICR',
#  'KAYS',
# ...

# %% [markdown]
# ## Section 6-Histograms: Use the DataFrame's hist() function to create a histogram for each numerical column.

# %%
weather_events_df.hist()
# Out:
# array([[<Axes: title={'center': 'Precipitation(in)'}>,
#         <Axes: title={'center': 'LocationLat'}>],
#        [<Axes: title={'center': 'LocationLng'}>,
#         <Axes: title={'center': 'ZipCode'}>]], dtype=object)

# %% [markdown]
# ## Section 7-List: Get some of your information into a list. Process each item in the list (use for or comprehensions as you like).

# %% [markdown]
# #### Creating a list of event types recorded in Colorado state

# %%
Event_type_values = [row.Type for _, row in weather_events_df.iterrows() if row.State == 'CO']

Event_type_values
# Out:
# ['Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Fog',
#  'Snow',
#  'Fog',
#  'Snow',
#  'Cold',
#  'Fog',
#  'Fog',
#  'Snow',
#  'Fog',
#  'Fog',
#  'Cold',
#  'Cold',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Fog',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Cold',
#  'Storm',
#  'Storm',
#  'Cold',
#  'Rain',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Storm',
#  'Storm',
#  'Storm',
#  'Storm',
#  'Storm',
#  'Storm',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Storm',
#  'Storm',
#  'Storm',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Snow',
#  'Fog',
#  'Snow',
#  'Rain',
#  'Rain',
#  'Rain',
#  'Rain',
#  'Rain',
#  'Rain',
#  'Rain',
#  'Rain',
# ...

# %% [markdown]
# ## Section 8-Filter: Use filter() to show only part of the information.

# %% [markdown]
# #### Filtering Dataset to have only Event Type, Severity and City

# %%
weather_events_df.filter(items=['Type', 'Severity', 'City'])
# Out:
#          Type  Severity      City
# 0        Snow     Light  Saguache
# 1        Snow     Light  Saguache
# 2        Snow     Light  Saguache
# 3        Snow     Light  Saguache
# 4        Snow     Light  Saguache
# ...       ...       ...       ...
# 8627176  Snow     Light    Lander
# 8627177  Snow  Moderate    Lander
# 8627178  Cold    Severe    Lander
# 8627179  Cold    Severe    Lander
# 8627180  Cold    Severe    Lander
#
# [8627181 rows x 3 columns]

# %% [markdown]
# ## Section 9-Map: Use map() to transform some of the data.

# %% [markdown]
# #### Converting Severity value from UNK to unknown

# %%
print(weather_events_df.Severity.unique())

weather_events_df.Severity = weather_events_df.Severity.map(lambda x : 'Unknown' if x == 'UNK' else x)

weather_events_df.Severity.unique()
# Out:
# ['Light' 'Severe' 'Moderate' 'Heavy' 'UNK' 'Other']
# array(['Light', 'Severe', 'Moderate', 'Heavy', 'Unknown', 'Other'],
#       dtype=object)
